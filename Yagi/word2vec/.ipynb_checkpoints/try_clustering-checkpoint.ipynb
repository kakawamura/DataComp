# %% [markdown]
# # クラスタリングしてみる
# ---
# word2vec -> clustering -> t-SNE の流れでクラスタを確認してみる。

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from gensim.models import word2vec
from sklearn.manifold import TSNE

plt.rcParams['font.family'] = 'Osaka'
# Out:
# /Users/TakayukiYagi/.pyenv/versions/anaconda3-2.5.0/lib/python3.5/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")

# %% [markdown]
# ### 前処理として、word2vec -> t-SNE

# %%
data = word2vec.Text8Corpus("basket.txt")
model = word2vec.Word2Vec(data, size=50)

categorys = np.array(list(model.vocab.keys()))
X = np.vstack([model[categorys[c]] for c in range(len(categorys))])

model2 = TSNE(n_components=2)
Z = model2.fit_transform(X)
# Out:
# WARNING:gensim.models.word2vec:consider setting layer size to a multiple of 4 for greater performance

# %% [markdown]
# ### とりあえずk-means (k=25)

# %%
from sklearn.cluster import KMeans

K = 25 
model3 = KMeans(n_clusters=K).fit(X)
labels = model3.labels_

fig = plt.figure(figsize=(60, 60))
plt.scatter(Z[:,0], Z[:,1], s=200, c=labels)
for i in range(len(categorys)):
    x = Z[i, 0]
    y = Z[i, 1]
    plt.text(x, y, categorys[i])

# %%
for k in range(K):
    cluster = categorys[labels == k]
    print("\n----------------------------------\ncluster%d\n" %k)
    for c in cluster:
        print(c)
# Out:
# ----------------------------------
# cluster0
#
# トレンチコート
# つなぎ/オールインワン
# デニムスカート
# キャミソール
# イヤリング
# パンプス
# ムートンコート
# ドレス
# ニット/セーター
# スカート
# レインシューズ
# ノーカラージャケット
# タンクトップ
# ボストンバッグ
# ブーティ
# サロペット/オーバーオール
# バレエシューズ
# かごバッグ
# その他トップス
# チューブトップ
# ショルダーバッグ
# ハンドバッグ
# サンダル
#
# ----------------------------------
# cluster1
#
# マフラー/ショール
# 手袋
# ネックウォーマー
# イヤーマフ
#
# ----------------------------------
# cluster2
#
# ペン類
# ヘアケア
# 石鹸/ボディソープ
# バンダナ/スカーフ
# メイクアップ
# お香/ルームフレグランス
# その他コスメ
# 入浴剤
# 食器
# その他雑貨
# ハンカチ/ハンドタオル
# グラス/マグカップ/タンブラー
# スキンケア
# エプロン
# バスタオル
# フェイスタオル
# オーラルケア/歯磨きグッズ
# ネイル/ハンドケア
# トラベルグッズ
# カトラリー
# ボディケア
# リップケア
# 長傘
# ステーショナリー
# 扇子/うちわ
# 手鏡/コンパクト
# 手帳/メモ帳
#
# ----------------------------------
# cluster3
#
# ポロシャツ
# テーラードジャケット
# チノパンツ
# スラックス
# カーゴパンツ
#
# ----------------------------------
# cluster4
#
# モッズコート
# スウェット
# ダウンジャケット/コート
# ブルゾン
# パンツ
# マウンテンパーカー
# ライダースジャケット
# シャツ/ブラウス
# デニムパンツ
# ナイロンジャケット
# チェスターコート
# Tシャツ/カットソー
# スタジャン
# ピーコート
# パーカー
# ステンカラーコート
# デニムジャケット
# メッセンジャーバッグ
# ダウンベスト
# ミリタリージャケット
# カバーオール
# ジャージ
#
# ----------------------------------
# cluster5
#
# リング
# ピアス（片耳用）
# ピアス（両耳用）
#
# ----------------------------------
# cluster6
#
# カーディガン
# ベスト
# その他アウター
# シャツワンピース
# ブーツ
# ワンピース
# ポンチョ
# アンサンブル
# ダッフルコート
# ストール/スヌード
# チュニック
#
# ----------------------------------
# cluster7
#
# マタニティグッズ
# マザーバッグ/収納ポーチ
# マタニティウェア
# ベビーギフト
# ベビー用品
# 肌着
# 母子手帳ケース
# スタイ/よだれかけ
# ロンパース
# レッグウォーマー
# ベビーシューズ
# お食事グッズ
#
# ----------------------------------
# cluster8
#
# ショーツ
# ブラ
#
# ----------------------------------
# cluster9
#
# ネックレス
# バングル/リストバンド
# ブレスレット
#
# ----------------------------------
# cluster10
#
# モバイルケース/カバー
# ボディバッグ/ウエストポーチ
# コインケース/札入れ
# モバイルアクセサリー
# 財布
# キーホルダー
# ポーチ
# パスケース
# キーケース/キーアクセサリー
# トートバッグ
# カードケース
#
# ----------------------------------
# cluster11
#
# モカシン/デッキシューズ
#
# ----------------------------------
# cluster12
#
# レギンス/スパッツ
# エコバッグ
# カチューシャ
# 雑誌
# ヘアバンド
# バレッタ/ヘアクリップ
# その他ヘアアクセサリー
# その他小物
# ブローチ/コサージュ
#
# ----------------------------------
# cluster13
#
# フォトフレーム
# キッチンツール
# ステッカー/テープ
# クッション/クッションカバー
# インテリアアクセサリー
# フラワーベース
# キャンドル
# ダストボックス
# ルームシューズ/スリッパ
# ラグ/マット
# 照明
# おもちゃ
# ブランケット
# ランドリーグッズ
# 収納グッズ
# バス/トイレグッズ
# 家具
# ベッドリネン
#
# ----------------------------------
# cluster14
#
# ボクサーパンツ
#
# ----------------------------------
# cluster15
#
# シュシュ
# ヘアゴム
#
# ----------------------------------
# cluster16
#
# ルームウェア
#
# ----------------------------------
# cluster17
#
# スーツスカート
# サスペンダー
# ハンチング/ベレー帽
# 置時計
# その他
# ラッピングキット
# ハット
# シューケア/シューズ小物
# スポーツグッズ
# フィギュア
# 生活家電/PCグッズ
# レインコート/ポンチョ
# バックパック/リュック
# ペットグッズ
# メガネ
# 着物/浴衣
# スーツケース/キャリーバッグ
# 本
# ギフトセット
# ウォレットチェーン
# メイク雑貨
# アッシュトレイ/ライター
# キャスケット
# ポスター/アート
# 香水
# スーツベスト
# ベビーカー用品
# その他シューズ
# 福袋/福箱
# バッジ
# オーディオ家電
# ドラムバッグ
# 折りたたみ傘
# 掛け時計
# サングラス
# ニットキャップ/ビーニー
# カフリンクス
# CD
# キッチン家電
# パスポートケース
# チャーム
# ミラー
# クラッチバッグ
# スニーカー
# サンバイザー
# 和装小物
# カメラ/カメラグッズ
# 名刺入れ
#
# ----------------------------------
# cluster18
#
# その他アンダーウェア/インナー
#
# ----------------------------------
# cluster19
#
# キャップ
# セットアップ
# スーツジャケット
# ゴルフグッズ
# スーツパンツ
# トランクス
# ドレスシューズ
# ソックス/靴下
# ビジネスバッグ
# ネクタイ
# ネクタイピン
# 蝶ネクタイ
# ベルト
#
# ----------------------------------
# cluster20
#
# ブラ&ショーツ
#
# ----------------------------------
# cluster21
#
# アンクレット
#
# ----------------------------------
# cluster22
#
# タイツ/ストッキング
#
# ----------------------------------
# cluster23
#
# ビーチサンダル
# スイムグッズ
# 水着
#
# ----------------------------------
# cluster24
#
# 腕時計

# %% [markdown]
# うまく分かれているクラスターもある（cluster8とか)けど、全体的にひどい。
# ユークリッド距離は適してないのかも。（word2vecは類似度をコサイン類似度で測っている）
#
# それからt-SNEがあまりうまくいってないようなきがする。

# %% [markdown]
# ### x-meansでリベンジ

# %%
import x_means

model4 = x_means.XMeans().fit(X)
# Out:
# /Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/word2vec/x_means.py:73: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if index == None:
# /Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/word2vec/x_means.py:73: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if index == None:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-9-872f938bc9e4> in <module>()
#       1 import x_means
#       2
# ----> 3 model4 = x_means.XMeans().fit(X)
#
# /Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/word2vec/x_means.py in fit(self, X)
#      30
#      31         clusters = self.Cluster.build(X, KMeans(self.k_init, **self.k_means_args).fit(X))
# ---> 32         self.__recursively_split(clusters)
#      33
#      34         self.labels_ = np.empty(X.shape[0], dtype = np.intp)
#
# /Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/word2vec/x_means.py in __recursively_split(self, clusters)
#      57             beta = np.linalg.norm(c1.center - c2.center) / np.sqrt(np.linalg.det(c1.cov) + np.linalg.det(c2.cov))
#      58             alpha = 0.5 / stats.norm.cdf(beta)
# ---> 59             bic = -2 * (cluster.size * np.log(alpha) + c1.log_likelihood() + c2.log_likelihood()) + 2 * cluster.df * np.log(cluster.size)
#      60
#      61             if bic < cluster.bic():
#
# /Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/word2vec/x_means.py in log_likelihood(self)
#      87
#      88         def log_likelihood(self):
# ---> 89             return sum(stats.multivariate_normal.logpdf(x, self.center, self.cov) for x in self.data)
#      90
#      91         def bic(self):
#
# /Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/word2vec/x_means.py in <genexpr>(.0)
#      87
#      88         def log_likelihood(self):
# ---> 89             return sum(stats.multivariate_normal.logpdf(x, self.center, self.cov) for x in self.data)
#      90
#      91         def bic(self):
#
# /Users/TakayukiYagi/.pyenv/versions/anaconda3-2.5.0/lib/python3.5/site-packages/scipy/stats/_multivariate.py in logpdf(self, x, mean, cov, allow_singular)
#     476         dim, mean, cov = self._process_parameters(None, mean, cov)
#     477         x = self._process_quantiles(x, dim)
# --> 478         psd = _PSD(cov, allow_singular=allow_singular)
#     479         out = self._logpdf(x, mean, psd.U, psd.log_pdet, psd.rank)
#     480         return _squeeze_output(out)
#
# /Users/TakayukiYagi/.pyenv/versions/anaconda3-2.5.0/lib/python3.5/site-packages/scipy/stats/_multivariate.py in __init__(self, M, cond, rcond, lower, check_finite, allow_singular)
#     153         d = s[s > eps]
#     154         if len(d) < len(s) and not allow_singular:
# --> 155             raise np.linalg.LinAlgError('singular matrix')
#     156         s_pinv = _pinv_1d(s, eps)
#     157         U = np.multiply(u, np.sqrt(s_pinv))
#
# LinAlgError: singular matrix

# %% [markdown]
# 撃沈。（多分うまくいかないからやめる）
