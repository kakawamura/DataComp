# %% [markdown]
# # t-SNEに挑戦
# ---
# sciket-learnを使ってt-SNEを試してみる．

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from gensim.models import word2vec
from sklearn.manifold import TSNE

plt.rcParams['font.family'] = 'Osaka'
# Out:
# /Users/TakayukiYagi/.pyenv/versions/anaconda3-2.5.0/lib/python3.5/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")

# %% [markdown]
# ### まずはword2vec

# %%
data = word2vec.Text8Corpus("basket.txt")
model = word2vec.Word2Vec(data, size=100, iter=30)

# %%
category = list(model.vocab.keys())
X = np.vstack([model[category[c]] for c in range(len(category))])

# %% [markdown]
# ### t-SNEを学習

# %%
model2 = TSNE(n_components=2, n_iter=5000)
Z = model2.fit_transform(X)

# %% [markdown]
# ### いざ可視化

# %%
plt.scatter(Z[:,0], Z[:,1])

# %% [markdown]
# ダマになってる...。うれしくない展開
# とりあえず、各カテゴリーの位置を確認

# %%
fig = plt.figure(figsize=(80, 80))
plt.scatter(Z[:,0], Z[:,1])
for i in range(len(category)):
    x = Z[i, 0]
    y = Z[i, 1]
    plt.text(x, y, category[i])
