# %%
% matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
path = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log_2016-11-26-18/log_2016-11-26-18_K5_P12_I100/itemdist/'

def idx2color(idx):
    D = {0:'red', 1:'blue', 2:'yellow', 3:'green', 4:'pink'}
    return D[idx]

def f(path):
    files = os.listdir(path)
    col_name = np.loadtxt(path + 'itemdist_columns.txt', delimiter=',', dtype=int)
    
    itemdists = []
    for i in range(12):
        tmp = np.loadtxt(path + files[i], delimiter=',')
        itemdists.append(tmp)
        
    colors = list(map(idx2color, col_name))

# %%
files = os.listdir('/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log_2016-11-26-18/log_2016-11-26-18_K5_P12_I100/itemdist/')
col_name = np.loadtxt('/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log_2016-11-26-18/log_2016-11-26-18_K5_P12_I100/itemdist/itemdist_columns.txt', delimiter=',', dtype=int)

itemdists = []
for i in range(12):
    tmp = np.loadtxt('/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log_2016-11-26-18/log_2016-11-26-18_K5_P12_I100/itemdist/' + files[i], delimiter=',')
    itemdists.append(tmp)

# %%
def idx2color(idx):
    D = {0:'red', 1:'blue', 2:'yellow', 3:'green', 4:'pink'}
    return D[idx]

colors = list(map(idx2color, col_name))

# %%
fig, axes = plt.subplots(12, 5, figsize=(30, 30))
x = np.arange(5)

for i in range(12):
    for j in range(5):
        axes[i, j].bar(x,itemdists[i][j], color=colors, alpha=0.7)
        if i==0:
            axes[i, j].set_title('cluster%d' %j)
        if j==0:
            axes[i, j].set_ylabel('month%d'  %i)
        axes[i, j].set_xticks(x+0.5)
        axes[i, j].set_xticklabels(colors)
