# %%
% matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from gensim.models import word2vec

# %% [markdown]
# word2vecで商品をベクトル化する

# %%
data = word2vec.Text8Corpus("basket.txt")
model = word2vec.Word2Vec(sentences=data, sg=1, size=200, window=5, negative=5, iter=30, min_count=0)

# %%
item_id = np.array(list(model.vocab.keys()))
X = np.vstack([model[item_id[i]] for i in range(len(item_id))])

# %% [markdown]
# 可視化のために２次元へ射影

# %%
from sklearn.decomposition import PCA
Z = PCA(n_components=2).fit_transform(X)

# %%
fig = plt.figure(figsize=(10, 10))
plt.scatter(Z[:,0], Z[:,1], s=1, marker='x', c='k')

# %%
from sklearn.cluster import KMeans

distortions = []
for i in range(1, 30):
    km = KMeans(n_clusters=i, init='k-means++', random_state=0).fit(X)
    distortions.append(km.inertia_)
    
fig = plt.figure(figsize=(10, 10))
plt.plot(range(1, 30), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')

# %%
xmeans = x_means.XMeans().fit(X)
#print(xmeans.labels_)
#print(xmeans.cluster_centers_)
#print(xmeans.cluster_log_likelihoods_)
#print(xmeans.cluster_sizes_)

fig = plt.figure(figsize=(10, 10))
plt.scatter(Z[:,0], Z[:,1], c=xmeans.labels_, marker='x')
# Out:
# [0 2 3 ..., 3 0 0]
# [[ -7.14778528e-02   2.01480780e-02  -1.14224099e-01   3.08908373e-02
#     2.10778162e-01  -1.23696633e-01  -1.36374220e-01   6.43144920e-02
#    -1.06866390e-01  -7.40823746e-02   9.94061381e-02  -2.15062797e-02
#    -1.41825661e-01  -2.96932869e-02  -1.01233505e-01  -4.69741635e-02
#     1.00332059e-01   1.32210881e-01  -2.03138385e-02   4.34913516e-01
#    -1.76521088e-03   1.67577177e-01  -1.97794121e-02   2.55272806e-01
#    -6.75331727e-02   1.39324680e-01   5.40908538e-02  -8.73442069e-02
#     7.34149963e-02   2.42443204e-01  -1.66723877e-01   8.69132206e-02
#    -2.53550529e-01   1.79986618e-02  -7.37561062e-02   1.44722328e-01
#     4.03237194e-02   1.01004854e-01   4.69031930e-02   7.15207160e-02
#     1.20625068e-02  -2.72668675e-02   5.12611866e-02  -2.09361792e-01
#     1.04063682e-01  -4.40725386e-02  -9.97135341e-02   4.37145717e-02
#    -2.48732150e-01   3.71563919e-02   5.56167439e-02   8.20882842e-02
#     1.07530020e-02   6.57519512e-03   6.92221373e-02  -1.09088354e-01
#    -1.94518119e-01  -8.27797055e-02  -1.61133438e-01  -2.99367681e-03
#     1.32674932e-01  -1.75648838e-01  -6.96775690e-02  -9.31308866e-02
#    -2.62503922e-01   1.48768220e-02  -1.09687775e-01   3.24794836e-03
#    -1.51001677e-01   1.36715174e-01  -7.58208241e-03  -1.36574596e-01
#    -1.75202325e-01   3.24937254e-02  -8.73321518e-02  -2.34333351e-01
#     1.29725546e-01  -5.63651286e-02  -1.06046699e-01  -2.04437859e-02
#     3.54602896e-02  -2.73871422e-01  -1.00436941e-01   6.75328821e-02
#    -1.21909194e-02   1.53720051e-01   9.59478915e-02   1.17309317e-01
#     8.17256421e-03  -1.14078179e-01  -7.82453120e-02   1.13754347e-02
#    -2.72640567e-02  -9.52986442e-03   6.71606883e-03  -9.84826535e-02
#     7.34950751e-02  -1.76064149e-02   1.00519001e-01   1.70003831e-01
#     5.88499978e-02  -1.52237406e-02   1.34365544e-01   7.18507841e-02
#    -1.27084106e-01  -1.10108510e-01  -3.72346714e-02  -1.22060422e-02
#    -1.35277092e-01   3.73335816e-02  -8.35535973e-02  -5.69502190e-02
#    -1.43648580e-01   1.03681691e-01   1.13498904e-01   6.53525069e-02
#     1.38307706e-01   4.76064831e-02  -9.89029258e-02   9.91702378e-02
#     1.75611407e-01  -1.17129274e-03  -2.60506898e-01   5.66642024e-02
#    -6.28165826e-02   6.24699406e-02  -7.81652704e-03  -1.63387686e-01
#    -1.29628897e-01  -1.62532464e-01   3.90484184e-02  -1.56190485e-01
#     4.57596108e-02   1.11131705e-01   3.83098796e-02  -2.02566117e-01
#    -2.52230875e-02   1.90751299e-01  -1.44761443e-01  -3.94756906e-02
#     7.63332993e-02  -4.60971817e-02  -1.21766359e-01   7.39493221e-02
#     9.66026783e-02   1.71505854e-01   9.54274088e-02   3.72170173e-02
#    -3.38473991e-02  -1.49757206e-01   3.95142213e-02  -1.49980932e-01
#    -1.30200371e-01  -8.11876133e-02  -1.51976913e-01  -2.63498314e-02
#    -6.04778230e-02   7.09822476e-02   3.14578414e-02  -1.30584717e-01
#    -3.92488614e-02   1.64904520e-01   1.03005633e-01   1.02897644e-01
#     1.24935493e-01  -1.35836095e-01  -4.96257842e-02  -7.90192783e-02
#     5.57540543e-02  -1.55192494e-01  -5.76349571e-02  -1.01070091e-01
#     2.90077310e-02   1.71119675e-01  -1.65327676e-02   4.08370793e-02
#     5.64931706e-02   2.19887551e-02  -3.98017578e-02  -5.65457046e-02
#    -5.93183897e-02   2.48080250e-02   7.17106611e-02   7.54363835e-04
#    -3.40573005e-02   2.95503866e-02  -1.81393623e-01  -3.45414653e-02
#    -1.42399266e-01  -1.93696976e-01  -1.37924805e-01  -3.63444462e-02
#     2.59662956e-01   5.99616468e-02  -5.82569651e-03   1.20561346e-01
#    -4.07403745e-02   5.46514168e-02   6.35528043e-02  -1.26586661e-01
#    -2.52760462e-02  -9.95246619e-02  -2.39123791e-01  -9.56747681e-02]]
# [ 1124077.97342582  2398596.23642081  1658147.18554327  5242036.88345431
#   2194241.11255096]
# [1872 3546 2835 7809 3831]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/TakayukiYagi/.pyenv/versions/anaconda3-2.5.0/lib/python3.5/site-packages/matplotlib/colors.py in to_rgba(self, arg, alpha)
#     367                     raise ValueError(
# --> 368                             'length of rgba sequence should be either 3 or 4')
#     369             else:
#
# ValueError: length of rgba sequence should be either 3 or 4
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /Users/TakayukiYagi/.pyenv/versions/anaconda3-2.5.0/lib/python3.5/site-packages/matplotlib/colors.py in to_rgba_array(self, c, alpha)
#     398             # Single value? Put it in an array with a single row.
# --> 399             return np.array([self.to_rgba(c, alpha)], dtype=np.float)
#     400         except ValueError:
#
# /Users/TakayukiYagi/.pyenv/versions/anaconda3-2.5.0/lib/python3.5/site-packages/matplotlib/colors.py in to_rgba(self, arg, alpha)
#     375             raise ValueError(
# --> 376                 'to_rgba: Invalid rgba arg "%s"\n%s' % (str(arg), exc))
#     377
#
# ValueError: to_rgba: Invalid rgba arg "[0 2 3 ..., 3 0 0]"
# length of rgba sequence should be either 3 or 4
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-43cdb6704b57> in <module>()
#       7 # 結果をプロット
#       8 plt.rcParams["font.family"] = "Hiragino Kaku Gothic Pro"
# ----> 9 plt.scatter(z[:,0], z[:,1], c = xmeans.labels_, s = 30)
#      10 plt.scatter(xmeans.cluster_centers_[:,0], xmeans.cluster_centers_[:,1], c = "r", marker = "+", s = 100)
#      11 plt.title("x-means_test1")
#
# /Users/TakayukiYagi/.pyenv/versions/anaconda3-2.5.0/lib/python3.5/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3249                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3250                          linewidths=linewidths, verts=verts,
# -> 3251                          edgecolors=edgecolors, data=data, **kwargs)
#    3252     finally:
#    3253         ax.hold(washold)
#
# /Users/TakayukiYagi/.pyenv/versions/anaconda3-2.5.0/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /Users/TakayukiYagi/.pyenv/versions/anaconda3-2.5.0/lib/python3.5/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3891                 offsets=offsets,
#    3892                 transOffset=kwargs.pop('transform', self.transData),
# -> 3893                 alpha=alpha
#    3894                 )
#    3895         collection.set_transform(mtransforms.IdentityTransform())
#
# /Users/TakayukiYagi/.pyenv/versions/anaconda3-2.5.0/lib/python3.5/site-packages/matplotlib/collections.py in __init__(self, paths, sizes, **kwargs)
#     829         """
#     830
# --> 831         Collection.__init__(self, **kwargs)
#     832         self.set_paths(paths)
#     833         self.set_sizes(sizes)
#
# /Users/TakayukiYagi/.pyenv/versions/anaconda3-2.5.0/lib/python3.5/site-packages/matplotlib/collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     115
#     116         self.set_edgecolor(edgecolors)
# --> 117         self.set_facecolor(facecolors)
#     118         self.set_linewidth(linewidths)
#     119         self.set_linestyle(linestyles)
#
# /Users/TakayukiYagi/.pyenv/versions/anaconda3-2.5.0/lib/python3.5/site-packages/matplotlib/collections.py in set_facecolor(self, c)
#     610             c = mpl.rcParams['patch.facecolor']
#     611         self._facecolors_original = c
# --> 612         self._facecolors = mcolors.colorConverter.to_rgba_array(c, self._alpha)
#     613         self.stale = True
#     614
#
# /Users/TakayukiYagi/.pyenv/versions/anaconda3-2.5.0/lib/python3.5/site-packages/matplotlib/colors.py in to_rgba_array(self, c, alpha)
#     401             if isinstance(c, np.ndarray):
#     402                 if c.ndim != 2 and c.dtype.kind not in 'SU':
# --> 403                     raise ValueError("Color array must be two-dimensional")
#     404                 if (c.ndim == 2 and c.shape[1] == 4 and c.dtype.kind == 'f'):
#     405                     if (c.ravel() > 1).any() or (c.ravel() < 0).any():
#
# ValueError: Color array must be two-dimensional

# %%
def label2color(label):
    colors = ['red', 'blue', 'green', 'yellow', 'pink']
    return colors[label]

fig = plt.figure(figsize=(10, 10))
color_label = list(map(label2color, xmeans.labels_))
plt.scatter(Z[:,0], Z[:,1], c=color_label, marker='x')

# %%
item_table = pd.read_csv("/Users/TakayukiYagi/Developer/M1/competition/data/item_analyzed.csv")
df = pd.DataFrame(np.array([item_id, xmeans.labels_]).T, columns=['item_id', 'label'], dtype=np.int)
df = pd.merge(df, item_table, left_on='item_id', right_on='new_item_id', how='left').dropna()

# %%
df.head()
# Out:
#    item_id_x  label  new_item_id  item_id_y  item_detail_id             color  \
# 0     418458      0       418458     256516               9  ネイビー
# 1      34141      2        34141      21004               1  その他1
# 2     430347      3       430347     263465               4  ネイビー
# 3     461439      3       461439     282126               2  カーキブラウン
# 4     200659      1       200659     121773               5  その他1
#
#      color_category              size   item_category_1   item_category_2  \
# 0  ブルー系              MEDIUM            トップス              ニット/セーター
# 1  その他               FREE              レッグウェア            ソックス/靴下
# 2  ブルー系              MEDIUM            トップス              パーカー
# 3  ブラウン系             ONE               ジャケット/アウター        その他アウター
# 4  その他               FREE              バッグ               クラッチバッグ
#
#    shop_id
# 0      346
# 1      346
# 2      244
# 3       75
# 4       15

# %%
cat1_list = list(set(df['item_category_1']))
cat1_count = []

for k in range(5):
    df_tmp = df[df['label']==k]
    cat1_count_tmp = []
    for cat in cat1_list:
        cat1_count_tmp.append(sum(df_tmp['item_category_1']==cat))
    cat1_count.append(cat1_count_tmp)

# %%
x = np.arange(len(cat1_count[0]))
fig = plt.figure(figsize=(10, 10))

for k in range(5):
    ax[k] = fig.add_subplot(5,1, k)
    ax[k].bar(x, cat1_count[i])
# Out:
# <Container object of 16 artists>
