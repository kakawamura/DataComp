# %%
% matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
import os

# %%
def idx2color(idx):
    D = {0:'red', 1:'blue', 2:'green', 3:'yellow', 4:'pink'}
    return D[idx]

def f(path, K):
    files = os.listdir(path)
    col_name = np.loadtxt(path + 'itemdist_columns.txt', delimiter=',', dtype=int)
    
    itemdists = []
    for i in range(12):
        tmp = np.loadtxt(path + files[i], delimiter=',')
        itemdists.append(tmp)
        
    colors = list(map(idx2color, col_name))
    
    fig, axes = plt.subplots(12, K, figsize=(30, 30))
    x = np.arange(5)
    
    for i in range(12):
        for j in range(K):
            axes[i, j].bar(x,itemdists[i][j], color=colors, alpha=0.7)
            if i==0:
                axes[i, j].set_title('cluster%d' %j)
            if j==0:
                axes[i, j].set_ylabel('month%d'  %i)
            axes[i, j].set_xticks(x+0.5)
            axes[i, j].set_xticklabels(colors)

# %%
path1 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-12-20/log_2016-12-12-20-210240_K5_P12_I100/itemdist/'
f(path1, 5)

# %%
path2 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-12-20/log_2016-12-12-20-259686_K5_P12_I100/itemdist/'
f(path2, 5)

# %%
path3 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-12-20/log_2016-12-12-20-278788_K5_P12_I100/itemdist/'
f(path3, 5)

# %%
path4 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-12-20/log_2016-12-12-20-281448_K5_P12_I100/itemdist/'
f(path4, 5)

# %%
path5 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-12-20/log_2016-12-12-20-297546_K5_P12_I100/itemdist/'
f(path5, 5)

# %%
path6 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-12-20/log_2016-12-12-20-305326_K5_P12_I100/itemdist/'
f(path6, 5)

# %%
path7 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-12-20/log_2016-12-12-20-306170_K5_P12_I100/itemdist/'
f(path7, 5)

# %%
path8 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-12-20/log_2016-12-12-20-309146_K5_P12_I100/itemdist/'
f(path8, 5)

# %%
path9 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-12-20/log_2016-12-12-20-315186_K5_P12_I100/itemdist/'
f(path9, 5)

# %%
path10 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-12-20/log_2016-12-12-20-327021_K5_P12_I100/itemdist/'
f(path10, 5)
