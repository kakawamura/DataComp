# %%
% matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
import os

# %%
def idx2color(idx):
    D = {0:'red', 1:'blue', 2:'green', 3:'yellow', 4:'pink'}
    return D[idx]

def f(path, K):
    files = os.listdir(path)
    col_name = np.loadtxt(path + 'itemdist_columns.txt', delimiter=',', dtype=int)
    
    itemdists = []
    for i in range(13):
        tmp = np.loadtxt(path + files[i], delimiter=',')
        itemdists.append(tmp)
        
    colors = list(map(idx2color, col_name))
    
    fig, axes = plt.subplots(13, K, figsize=(30, 30))
    x = np.arange(5)
    
    for i in range(13):
        for j in range(K):
            axes[i, j].bar(x,itemdists[i][j], color=colors, alpha=0.7)
            if i==0:
                axes[i, j].set_title('cluster%d' %j)
            if j==0:
                axes[i, j].set_ylabel('month%d'  %i)
            axes[i, j].set_xticks(x+0.5)
            axes[i, j].set_xticklabels(colors)

# %%
path = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-13-16/log_2016-12-13-16-811231_K5_P13_I100/itemdist/'
files = os.listdir(path)
col_name = np.loadtxt(path + 'itemdist_columns.txt', delimiter=',', dtype=int)

itemdists = []
for i in range(13):
    tmp = np.loadtxt(path + files[i], delimiter=',')
    itemdists.append(tmp)
    
colors = list(map(idx2color, col_name))

fig = plt.figure(figsize=(10,10))
x = np.arange(5)

i = 0

j = 0
plt.bar(x,itemdists[0][0], color=colors, alpha=0.7)
plt.title('cluster%d' %j)
plt.label('month%d'  %i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-034f8fce1675> in <module>()
#      18 plt.bar(x,itemdists[0][0], color=colors, alpha=0.7)
#      19 plt.title('cluster%d' %j)
# ---> 20 plt.label('month%d'  %i)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'label'

# %%
def idx2color(idx):
    D = {0:'red', 1:'blue', 2:'green', 3:'yellow', 4:'pink'}
    return D[idx]

def f(path, K):
    files = os.listdir(path)
    col_name = np.loadtxt(path + 'itemdist_columns.txt', delimiter=',', dtype=int)
    
    itemdists = []
    for i in range(13):
        tmp = np.loadtxt(path + files[i], delimiter=',')
        itemdists.append(tmp)
        
    colors = list(map(idx2color, col_name))
    
    fig, axes = plt.subplots(2, K, figsize=(30, 10))
    x = np.arange(5)
    
    for i in range(1):
        for j in range(K):
            axes[i, j].bar(x,itemdists[i][j], color=colors, alpha=0.7)
            if i==0:
                axes[i, j].set_title('cluster%d' %j)
            if j==0:
                axes[i, j].set_ylabel('month%d'  %i)
            axes[i, j].set_xticks(x+0.5)
            axes[i, j].set_xticklabels(colors)
            
path1 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-13-16/log_2016-12-13-16-811231_K5_P13_I100/itemdist/'
f(path1, 5)

# %%
path1 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-13-16/log_2016-12-13-16-811231_K5_P13_I100/itemdist/'
f(path1, 5)

# %%
path2 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-13-16/log_2016-12-13-16-811245_K5_P13_I100/itemdist/'
f(path2, 5)

# %%
path3 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-13-16/log_2016-12-13-16-811247_K5_P13_I100/itemdist/'
f(path3, 5)

# %%
path4 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-13-16/log_2016-12-13-16-811251_K5_P13_I100/itemdist/'
f(path4, 5)

# %%
path5 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-13-16/log_2016-12-13-16-811312_K5_P13_I100/itemdist/'
f(path5, 5)

# %%
path6 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-13-16/log_2016-12-13-16-811314_K5_P13_I100/itemdist/'
f(path6, 5)

# %%
path7 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-13-16/log_2016-12-13-16-811315_K5_P13_I100/itemdist/'
f(path7, 5)

# %%
path8 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-13-16/log_2016-12-13-16-811322_K5_P13_I100/itemdist/'
f(path8, 5)

# %%
path9 = '/Users/TakayukiYagi/Developer/M1/competition/DataComp/Yagi/TTM/log/log_2016-12-13-16/log_2016-12-13-16-811322_K5_P13_I100/itemdist/'
f(path9, 5)
